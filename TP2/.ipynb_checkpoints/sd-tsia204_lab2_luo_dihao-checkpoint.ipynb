# %%
# Change here using YOUR own first and last names
fn1 = "dihao"
ln1 = "luo"
filename = "_".join(map(lambda s: s.strip().lower(),
                        ["SD-TSIA204_lab2", ln1, fn1])) + ".ipynb"
print(filename)
# Out:
# sd-tsia204_lab2_luo_dihao.ipynb

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %matplotlib inline

# %%
raw_data = pd.read_csv("data_dm3.csv", header=-1)
raw_data.head()
# Out:
#         0         1         2         3         4         5         6    \
# 0 -1.298173 -0.162249  1.223379  1.355554  1.080171  0.634979  0.298741
# 1  0.166951 -0.338060 -0.618867  0.759366  1.134281 -0.536844 -0.075120
# 2 -0.416177 -0.205659 -1.282226  1.675500  1.523746  0.192029 -0.235840
# 3  0.867184 -0.398667  0.093501  0.025971  1.852099  0.789774  0.801775
# 4  1.193282 -0.936980 -0.725039  0.766078  0.223489 -1.584622  1.146866
#
#         7         8         9    ...         201       202       203  \
# 0  0.548270  0.731773  1.018645  ...    0.588278  0.210106  1.861458
# 1  0.970251 -0.327487  0.717310  ...   -0.251054 -0.825716  0.339139
# 2 -1.954626 -0.853309  0.892791  ...    1.283837  0.372516 -0.652557
# 3  0.376711  0.853689  0.247953  ...    0.446582  0.334733  0.399074
# 4  0.086136 -0.088780 -0.945066  ...    0.786157 -1.058179 -0.155788
#
#         204       205       206       207       208       209    210
# 0 -0.436399  0.279299 -1.416020 -2.332363  0.215096 -0.693319  151.0
# 1  1.119430  0.225958 -0.822288  0.382838 -0.718829 -0.188993   75.0
# 2 -2.579347  0.139267 -1.901196  0.048210  0.220205  0.471588  141.0
# 3 -0.884172  0.723819  1.316367  0.088218  0.619496  1.061662  206.0
# 4 -0.642504  2.040010 -1.703110 -1.901502  1.778811 -0.489853  135.0
#
# [5 rows x 211 columns]

# %%
raw_data.describe()
# Out:
#                 0             1             2             3             4    \
# count  4.420000e+02  4.420000e+02  4.420000e+02  4.420000e+02  4.420000e+02
# mean   7.535450e-19 -1.507090e-17  5.494599e-20 -7.284269e-18  8.288995e-18
# std    1.001133e+00  1.001133e+00  1.001133e+00  1.001133e+00  1.001133e+00
# min   -3.149247e+00 -2.862871e+00 -3.057543e+00 -2.856903e+00 -3.102347e+00
# 25%   -6.707870e-01 -7.128394e-01 -7.160981e-01 -6.715474e-01 -6.732232e-01
# 50%    3.819503e-02  6.217421e-02  4.739406e-02  6.565749e-05 -6.111315e-03
# 75%    6.748497e-01  6.244547e-01  6.975121e-01  6.881971e-01  7.026457e-01
# max    2.547051e+00  2.567177e+00  2.965824e+00  3.057612e+00  3.173713e+00
#
#                 5             6             7             8             9    \
# count  4.420000e+02  4.420000e+02  4.420000e+02  4.420000e+02  4.420000e+02
# mean  -2.712762e-17  1.971776e-17  8.540177e-18  1.029845e-17  4.018907e-18
# std    1.001133e+00  1.001133e+00  1.001133e+00  1.001133e+00  1.001133e+00
# min   -2.782344e+00 -2.825318e+00 -3.626525e+00 -2.834007e+00 -2.695861e+00
# 25%   -6.951004e-01 -6.986587e-01 -6.387691e-01 -6.666746e-01 -6.930021e-01
# 50%   -1.345167e-02 -4.823057e-02  4.016636e-02  6.047571e-04  3.602406e-02
# 75%    7.155790e-01  7.200217e-01  5.788436e-01  6.298078e-01  6.629150e-01
# max    3.137950e+00  3.199205e+00  3.616718e+00  3.099090e+00  3.032505e+00
#
#           ...               201           202           203           204  \
# count     ...      4.420000e+02  4.420000e+02  4.420000e+02  4.420000e+02
# mean      ...     -2.260635e-18 -2.637408e-17 -5.023634e-19 -1.538488e-17
# std       ...      1.001133e+00  1.001133e+00  1.001133e+00  1.001133e+00
# min       ...     -3.059475e+00 -3.206539e+00 -2.585325e+00 -3.561763e+00
# 25%       ...     -6.885118e-01 -5.793321e-01 -6.282190e-01 -6.190946e-01
# 50%       ...     -2.994795e-02  2.540540e-02 -2.229024e-02 -6.087758e-03
# 75%       ...      6.672697e-01  6.676636e-01  5.985077e-01  7.406183e-01
# max       ...      2.677458e+00  2.806877e+00  3.255462e+00  2.811911e+00
#
#                 205           206           207           208           209  \
# count  4.420000e+02  4.420000e+02  4.420000e+02  4.420000e+02  4.420000e+02
# mean   5.525997e-18  3.265362e-17  1.507090e-17 -4.034606e-18  1.205672e-17
# std    1.001133e+00  1.001133e+00  1.001133e+00  1.001133e+00  1.001133e+00
# min   -3.167962e+00 -2.751207e+00 -3.028940e+00 -2.675447e+00 -2.918321e+00
# 25%   -7.359866e-01 -6.374872e-01 -6.472739e-01 -7.025578e-01 -6.378171e-01
# 50%    7.677091e-03 -3.123603e-03  2.444578e-02 -4.187834e-02 -8.099075e-02
# 75%    7.000447e-01  6.440062e-01  6.313916e-01  6.929876e-01  7.249269e-01
# max    2.838960e+00  3.351254e+00  2.734481e+00  3.637684e+00  2.710260e+00
#
#               210
# count  442.000000
# mean   152.133484
# std     77.093005
# min     25.000000
# 25%     87.000000
# 50%    140.500000
# 75%    211.500000
# max    346.000000
#
# [8 rows x 211 columns]

# %% [markdown]
# ## Ex 1.1
#
# Provide the number of the exploratory variables and the number of the observations.
#
# ___
# So there are 211 variables in total, where 210 are the exploratory variables and 1 is the observation.

# %%
X = raw_data.iloc[:, :210]
Y = raw_data.iloc[:, 210]

# %% [markdown]
# ## Ex 1.2
#
# Are the exploratory variables centered? Normalized? And the output variable? Provide a scatter plot of four randomly chosen exploratory variables and the output variable (a scatter plot or a bi-plot/pairwise-plot plots all possible pairs of variables). Comment the obtained graphs.
# ___

# %%
X.describe()
# Out:
#                 0             1             2             3             4    \
# count  4.420000e+02  4.420000e+02  4.420000e+02  4.420000e+02  4.420000e+02
# mean   7.535450e-19 -1.507090e-17  5.494599e-20 -7.284269e-18  8.288995e-18
# std    1.001133e+00  1.001133e+00  1.001133e+00  1.001133e+00  1.001133e+00
# min   -3.149247e+00 -2.862871e+00 -3.057543e+00 -2.856903e+00 -3.102347e+00
# 25%   -6.707870e-01 -7.128394e-01 -7.160981e-01 -6.715474e-01 -6.732232e-01
# 50%    3.819503e-02  6.217421e-02  4.739406e-02  6.565749e-05 -6.111315e-03
# 75%    6.748497e-01  6.244547e-01  6.975121e-01  6.881971e-01  7.026457e-01
# max    2.547051e+00  2.567177e+00  2.965824e+00  3.057612e+00  3.173713e+00
#
#                 5             6             7             8             9    \
# count  4.420000e+02  4.420000e+02  4.420000e+02  4.420000e+02  4.420000e+02
# mean  -2.712762e-17  1.971776e-17  8.540177e-18  1.029845e-17  4.018907e-18
# std    1.001133e+00  1.001133e+00  1.001133e+00  1.001133e+00  1.001133e+00
# min   -2.782344e+00 -2.825318e+00 -3.626525e+00 -2.834007e+00 -2.695861e+00
# 25%   -6.951004e-01 -6.986587e-01 -6.387691e-01 -6.666746e-01 -6.930021e-01
# 50%   -1.345167e-02 -4.823057e-02  4.016636e-02  6.047571e-04  3.602406e-02
# 75%    7.155790e-01  7.200217e-01  5.788436e-01  6.298078e-01  6.629150e-01
# max    3.137950e+00  3.199205e+00  3.616718e+00  3.099090e+00  3.032505e+00
#
#            ...                200           201           202           203  \
# count      ...       4.420000e+02  4.420000e+02  4.420000e+02  4.420000e+02
# mean       ...       1.934099e-17 -2.260635e-18 -2.637408e-17 -5.023634e-19
# std        ...       1.001133e+00  1.001133e+00  1.001133e+00  1.001133e+00
# min        ...      -3.436711e+00 -3.059475e+00 -3.206539e+00 -2.585325e+00
# 25%        ...      -6.602634e-01 -6.885118e-01 -5.793321e-01 -6.282190e-01
# 50%        ...       4.227517e-02 -2.994795e-02  2.540540e-02 -2.229024e-02
# 75%        ...       6.433939e-01  6.672697e-01  6.676636e-01  5.985077e-01
# max        ...       2.737036e+00  2.677458e+00  2.806877e+00  3.255462e+00
#
#                 204           205           206           207           208  \
# count  4.420000e+02  4.420000e+02  4.420000e+02  4.420000e+02  4.420000e+02
# mean  -1.538488e-17  5.525997e-18  3.265362e-17  1.507090e-17 -4.034606e-18
# std    1.001133e+00  1.001133e+00  1.001133e+00  1.001133e+00  1.001133e+00
# min   -3.561763e+00 -3.167962e+00 -2.751207e+00 -3.028940e+00 -2.675447e+00
# 25%   -6.190946e-01 -7.359866e-01 -6.374872e-01 -6.472739e-01 -7.025578e-01
# 50%   -6.087758e-03  7.677091e-03 -3.123603e-03  2.444578e-02 -4.187834e-02
# 75%    7.406183e-01  7.000447e-01  6.440062e-01  6.313916e-01  6.929876e-01
# max    2.811911e+00  2.838960e+00  3.351254e+00  2.734481e+00  3.637684e+00
#
#                 209
# count  4.420000e+02
# mean   1.205672e-17
# std    1.001133e+00
# min   -2.918321e+00
# 25%   -6.378171e-01
# 50%   -8.099075e-02
# 75%    7.249269e-01
# max    2.710260e+00
#
# [8 rows x 210 columns]

# %%
# if the explorary variables are centered
all(abs(X.describe().iloc[1]) < 0.01)
# Out:
# True

# %%
# if the explorary variables are normalized
all(abs(X.describe().iloc[2]-1) < 0.01)
# Out:
# True

# %%
# if the observation variable is normalized and centered
Y.describe()
# Out:
# count    442.000000
# mean     152.133484
# std       77.093005
# min       25.000000
# 25%       87.000000
# 50%      140.500000
# 75%      211.500000
# max      346.000000
# Name: 210, dtype: float64

# %% [markdown]
# ___
# As we can see, the explorary variables are centered and normalized and the observation variable is neither centered nor normalized.
# ___

# %%
# Seaborn visualization library

import seaborn as sns

# %%
fig, axes = plt.subplots(5, 5, figsize=(15, 15))
col = np.random.randint(210, size=4).tolist()
col.append(210)
for i in range(5):
    for j in range(5):
        axes[i, j].scatter(raw_data.iloc[:, col[i]],
                           raw_data.iloc[:, col[j]], s=1)

# %%
col = np.random.randint(210, size=4)
for i in range(4):
    plt.scatter(X.iloc[:, col[i]], Y, s=3)
plt.show()

# Create the default pairplot
col = col.tolist()
col.append(210)
sns.pairplot(raw_data.iloc[:, col])

# %% [markdown]
# ___
# From the scatter plot and pairplot above, we can see there is no direct connection with those 4 randomly selected variables and the observation variable. This is because the bad robot has added 200 inappropriate exploratory variables. As a result, most of the exploratory variables are not coherent with the observation variable.

# %% [markdown]
# ## Ex 1.3
#
# Train and test sample. Create two samples: one to learn the model Xtrain and one to test it Xtest. Put 20% of the data set in the test sample. Provide the size of each of the 2 samples. Note that the new sample of the covariates Xtrain is not normalized. In what follows, please pay attention to include the intercept in the regression models.
#
# ___

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.2)

# %% [markdown]
# ---
#
# ## Ex 1.4
#
# Provide the covariance matrix for Xtrain. Plot the eigenvalues of the covariance (or correlation) matrix in descending order. Explain why does it make sense to keep only first PCA variables. In what follows, we will keep 60 variables.
#
# ___

# %%
X_train.cov()
# Out:
#           0         1         2         3         4         5         6    \
# 0    0.980746 -0.139498 -0.027627 -0.301146  0.162086  0.161253 -0.080075
# 1   -0.139498  0.985706  0.073077 -0.216633 -0.125992 -0.110983  0.179279
# 2   -0.027627  0.073077  0.962936 -0.225518  0.153045 -0.110518 -0.124057
# 3   -0.301146 -0.216633 -0.225518  1.009209  0.012576 -0.099473  0.123287
# 4    0.162086 -0.125992  0.153045  0.012576  1.004987 -0.025482  0.008614
#        2.83936182e-16, 3.61084141e-16, 3.61084141e-16, 3.57623377e-16,
#        2.83521042e-16, 2.83521042e-16, 2.31457891e-16, 2.31457891e-16,
#        1.82113967e-16, 1.82113967e-16, 1.70060863e-16, 1.70060863e-16,
#        2.59481366e-16, 2.59481366e-16, 1.13587196e-16, 1.13587196e-16,
#        2.56144158e-16, 2.56144158e-16, 2.62926936e-16, 1.10916911e-16,
#        1.10916911e-16, 1.99473219e-16, 4.91700433e-17, 8.25432185e-17,
#        2.08453268e-16, 2.18644476e-16])

# %%
plt.plot(np.sort(abs(eigen_value))[::-1])

# %% [markdown]
# ___
#
# As we can see from the image above, only first 60 variables have values and the rest is nearly 0. So in the following  process, they don't have much influence on the observation variables and it makes sense to keep only first PCA variables.

# %% [markdown]
# ---
#
# ## Ex 1.5
#
# Following the observations of the question (Q4), apply the method "PCA before OLS" that consists in applying OLS with Y and XtrainVp1:60q, where Vp1:60q contains the eigenvectors (associated with the 60 largest eigenvalues) of the covariance matrix. Run linear regression (with intercept), then plot the values of the coefficients (but not for the intercept). On another graph, do the same using the classical OLS.
#
# ___

# %%
# the indice of the 60 largest eigenvalues
ind = np.argsort(abs(eigen_value))[-60:]

# choose the associed eigenvectors
eigen_vector[ind].shape
# Out:
# (60, 210)

# %%
X_train_PCA = np.dot(X_train, eigen_vector[ind].transpose())

# %%
X_train_PCA.shape
# Out:
# (353, 60)

# %%
from sklearn.linear_model import LinearRegression

# %%
reg = LinearRegression().fit(X_train_PCA, y_train)
# Out:
# /usr/local/anaconda3/lib/python3.6/site-packages/sklearn/utils/validation.py:433: ComplexWarning: Casting complex values to real discards the imaginary part
#   array = np.array(array, dtype=dtype, order=order, copy=copy)

# %%
print(reg.coef_)
# Out:
# [  42.60943942   -8.62988044 -160.65633828   70.88412005 -240.82582895
#  -171.65186893  -75.49985183  -64.89906568 -127.91060502   97.6706851
#  -148.23826487  233.11871447  -68.91511991 -254.95568323 -163.73519877
#  -212.81196019  -20.9894641  -240.13092318   18.63847235  -65.54124928
#    22.90009058  188.55140659 -164.15004806   52.77987714  -46.75241944
#   198.79082739 -104.09889092  125.10902107  -25.69478719 -291.32755675
#   -11.46826229  -97.4027963  -108.04639934  157.33881939 -288.04902435
#   237.12105306  408.04316807  148.20700255  144.43064755 -126.95549026
#  -163.76114438   24.56546379  102.28628462   22.49183958  379.5767355
#   -66.81974391  -58.12502153  -40.27694386  -58.00902167 -115.48479667
#  -122.12513114  431.41838775  166.46916615 -183.89005034 -129.04988062
#  -380.31415012   50.10243292   79.95449099  118.37735075 -208.69975569]

# %%
plt.plot(reg.coef_)

# %%
reg_without_PCA = LinearRegression().fit(X_train, y_train)
# print(reg_without_PCA.coef_)
plt.plot(reg_without_PCA.coef_)

# %% [markdown]
# ---
#
# ## Ex 1.6
#
# Provide the intercept values for the 2 regressions from the previous question. Also, provide the mean value of the output variable Y (for the train set). Are the two intercepts equal? Comment. Exceptionally for this question, center and normalize the variables after PCA (the low dimensional ones). Run the regression and verify that the intercept is equal to the average of Y on the train set.
#
# ___

# %%
print('intercept of regrssion after PCA: ', reg.intercept_)
print('intercept of regrssion without PCA: ', reg_without_PCA.intercept_)
# Out:
# intercept of regrssion after PCA:  152.4469581791649
# intercept of regrssion without PCA:  152.07400849858357
